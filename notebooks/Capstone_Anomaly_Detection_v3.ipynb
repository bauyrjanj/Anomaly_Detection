# %% [markdown]
# # Capstone: Anomaly Detection - Step 2 Data Wrangling
#
# Data wrangling is the second step in the Data Science Method. This step consists of multiple components including Data Collection, Data Organization, Data Definitions, and Data Cleaning.

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   **Data Wrangling**
#   * Data Collection
#       - Locating the data
#       - Data loading
#       - Data joining
#    * Data Organization
#       -  File structure
#       -  Git & Github
#   * Data Definition
#       - Column names
#       - Data types (numeric, categorical, timestamp, etc.)
#       - Description of the columns
#       - Count or percent per unique values or codes (including NA)
#       - The range of values or codes
#   * Data Cleaning
#       - NA or missing data
#       - Duplicates
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.   Modeling
#
# 6.   Documentation

# %% [markdown]
# ## Data Collection
# <font color='teal'>**First, let's load the needed packages and modules into Python. Then I will load the dataset into pandas dataframe for ease of use.**</font>

# %%
import os
import numpy as np
import pandas as pd
import datetime
import kaggle as kg
import requests
from pathlib import Path
import pandas_profiling
from pandas_profiling.utils.cache import cache_file
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# <font color='teal'>**Set your working directory correctly**</font>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bauyrjan.Jyenis'

# %%
path = 'C:\\Users\\Bauyrjan.Jyenis\\Capstone2_Project\\capstone\\data\\raw'
os.chdir(path)

# %% [markdown]
# ## About the Data
#
# This data set represents sensor data from a pump in a production plant including the sensor data from the 7 system failures that occured last year. When occured, these failures cause production loss and likely lead to liquid overflows that pose environmental and safety risks. The Asset Management team in charge can't see any pattern in the data hence they adon't l know what the cause/s of the failures. They would like to identify the cause/s and put controls in place and most importantly they would like to be able to predict the next failure to become more proactive in mitigating risks before they become issues.

# %% [markdown]
# ### DON'T RUN THE CODE IN NEXT LINE AFTER THE INITIAL RUN !!!
#
# First, download the data set from Kaggle page https://www.kaggle.com/nphantawee/pump-sensor-data

# %%
# !kaggle datasets download -d nphantawee/pump-sensor-data
# Out:
# Downloading pump-sensor-data.zip to C:\Users\Bauyrjan.Jyenis\Capstone2_Project\capstone\data\raw
#   0%|          | 0.00/37.1M [00:00<?, ?B/s]
#   3%|2         | 1.00M/37.1M [00:00<00:20, 1.82MB/s]
#   5%|5         | 2.00M/37.1M [00:00<00:18, 2.03MB/s]
#   8%|8         | 3.00M/37.1M [00:01<00:17, 1.99MB/s]
#  11%|#         | 4.00M/37.1M [00:01<00:16, 2.08MB/s]
#  13%|#3        | 5.00M/37.1M [00:02<00:16, 2.09MB/s]
#  16%|#6        | 6.00M/37.1M [00:02<00:13, 2.43MB/s]
#  19%|#8        | 7.00M/37.1M [00:03<00:11, 2.66MB/s]
#  22%|##1       | 8.00M/37.1M [00:03<00:10, 3.04MB/s]
#  24%|##4       | 9.00M/37.1M [00:03<00:09, 3.02MB/s]
#  27%|##6       | 10.0M/37.1M [00:04<00:09, 2.91MB/s]
#  30%|##9       | 11.0M/37.1M [00:04<00:09, 2.76MB/s]
#  32%|###2      | 12.0M/37.1M [00:04<00:09, 2.72MB/s]
#  35%|###5      | 13.0M/37.1M [00:05<00:09, 2.80MB/s]
#  38%|###7      | 14.0M/37.1M [00:05<00:08, 2.82MB/s]
#  40%|####      | 15.0M/37.1M [00:05<00:07, 2.90MB/s]
#  43%|####3     | 16.0M/37.1M [00:06<00:07, 3.01MB/s]
#  46%|####5     | 17.0M/37.1M [00:06<00:06, 3.13MB/s]
#  49%|####8     | 18.0M/37.1M [00:06<00:06, 2.92MB/s]
#  51%|#####1    | 19.0M/37.1M [00:07<00:07, 2.48MB/s]
#  54%|#####3    | 20.0M/37.1M [00:07<00:06, 2.58MB/s]
#  57%|#####6    | 21.0M/37.1M [00:08<00:06, 2.69MB/s]
#  59%|#####9    | 22.0M/37.1M [00:08<00:06, 2.44MB/s]
#  62%|######2   | 23.0M/37.1M [00:09<00:06, 2.45MB/s]
#  65%|######4   | 24.0M/37.1M [00:09<00:05, 2.53MB/s]
#  67%|######7   | 25.0M/37.1M [00:09<00:04, 2.70MB/s]
#  70%|#######   | 26.0M/37.1M [00:10<00:05, 2.19MB/s]
#  73%|#######2  | 27.0M/37.1M [00:11<00:05, 2.06MB/s]
#  76%|#######5  | 28.0M/37.1M [00:11<00:04, 1.90MB/s]
#  78%|#######8  | 29.0M/37.1M [00:12<00:04, 1.81MB/s]
#  81%|########  | 30.0M/37.1M [00:12<00:03, 2.00MB/s]
#  84%|########3 | 31.0M/37.1M [00:13<00:02, 2.20MB/s]
#  86%|########6 | 32.0M/37.1M [00:13<00:02, 2.42MB/s]
#  89%|########9 | 33.0M/37.1M [00:13<00:01, 2.77MB/s]
#  92%|#########1| 34.0M/37.1M [00:14<00:01, 3.04MB/s]
#  94%|#########4| 35.0M/37.1M [00:14<00:00, 3.30MB/s]
#  97%|#########7| 36.0M/37.1M [00:14<00:00, 3.28MB/s]
# 100%|#########9| 37.0M/37.1M [00:15<00:00, 2.44MB/s]
# 100%|##########| 37.1M/37.1M [00:15<00:00, 2.54MB/s]

# %% [markdown]
# <font color='teal'>**Unzip the zip file to extract CSV files in the working directory**</font>

# %%
import zipfile
with zipfile.ZipFile('pump-sensor-data.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# <font color='teal'>**Read CSV files into pandas dataframes**</font>

# %%
df = pd.read_csv('sensor.csv')

# %%
df.shape
# Out:
# (220320, 55)

# %% [markdown]
# ## Data Definition (Data Profiling)

# %% [markdown]
# <font color='teal'>**Create and export data profile report using pandas-profiling package**</font>

# %%
profile_report = df.profile_report(html={'style': {'full_width': True}})
profile_report.to_file("df-profile_report.html")

# %% [markdown]
# <font color='teal'>**Look at the first and last 5 rows, columns and data types of the data set**</font>

# %%
df.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# 0  39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 1  39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 2  39.351852   65.39352   51.21528  38.194443   155.9606   67.12963
# 3  39.062500   64.81481   51.21528  38.194440   155.9606   66.84028
# 4  38.773150   65.10416   51.79398  38.773150   158.2755   66.55093
#
#    sensor_50  sensor_51  machine_status
# 0   243.0556   201.3889          NORMAL
# 1   243.0556   201.3889          NORMAL
# 2   241.3194   203.7037          NORMAL
# 3   240.4514   203.1250          NORMAL
# 4   242.1875   201.3889          NORMAL
#
# [5 rows x 55 columns]

# %%
df.tail()
# Out:
#         Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 220315      220315  2018-08-31 23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 220315  43.142361  634.722229   64.59095   15.11863   16.65220  ...
# 220316  43.142361  630.902771   65.83363   15.15480   16.70284  ...
# 220317  43.142361  625.925903   67.29445   15.08970   16.70284  ...
# 220318  43.142361  635.648100   65.09175   15.11863   16.56539  ...
# 220319  43.142361  639.814800   65.45634   15.11863   16.65220  ...
#
#         sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# 220315   38.28125   68.28703   52.37268   48.32176  41.087960   212.3843
# 220316   38.28125   66.84028   50.63657   48.03241  40.798610   213.8310
# 220317   39.06250   65.39352   48.90046   48.03241  40.798610   217.3032
# 220318   40.62500   64.23611   47.74306   48.32176  40.509258   222.5116
# 220319   41.40625   62.78935   46.29630   48.90046  40.219910   227.4306
#
#         sensor_49  sensor_50  sensor_51  machine_status
# 220315   153.6458        NaN   231.1921          NORMAL
# 220316   156.2500        NaN   231.1921          NORMAL
# 220317   155.3819        NaN   232.0602          NORMAL
# 220318   153.9352        NaN   234.0856          NORMAL
# 220319   150.4630        NaN   234.0856          NORMAL
#
# [5 rows x 55 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      220320 non-null  int64
#  1   timestamp       220320 non-null  object
#  2   sensor_00       210112 non-null  float64
#  3   sensor_01       219951 non-null  float64
#  4   sensor_02       220301 non-null  float64
#  5   sensor_03       220301 non-null  float64
#  6   sensor_04       220301 non-null  float64
#  7   sensor_05       220301 non-null  float64
#  8   sensor_06       215522 non-null  float64
#  9   sensor_07       214869 non-null  float64
#  10  sensor_08       215213 non-null  float64
#  11  sensor_09       215725 non-null  float64
#  12  sensor_10       220301 non-null  float64
#  13  sensor_11       220301 non-null  float64
#  14  sensor_12       220301 non-null  float64
#  15  sensor_13       220301 non-null  float64
#  16  sensor_14       220299 non-null  float64
#  17  sensor_15       0 non-null       float64
#  18  sensor_16       220289 non-null  float64
#  19  sensor_17       220274 non-null  float64
#  20  sensor_18       220274 non-null  float64
#  21  sensor_19       220304 non-null  float64
#  22  sensor_20       220304 non-null  float64
#  23  sensor_21       220304 non-null  float64
#  24  sensor_22       220279 non-null  float64
#  25  sensor_23       220304 non-null  float64
#  26  sensor_24       220304 non-null  float64
#  27  sensor_25       220284 non-null  float64
#  28  sensor_26       220300 non-null  float64
#  29  sensor_27       220304 non-null  float64
#  30  sensor_28       220304 non-null  float64
#  31  sensor_29       220248 non-null  float64
#  32  sensor_30       220059 non-null  float64
#  33  sensor_31       220304 non-null  float64
#  34  sensor_32       220252 non-null  float64
#  35  sensor_33       220304 non-null  float64
#  36  sensor_34       220304 non-null  float64
#  37  sensor_35       220304 non-null  float64
#  38  sensor_36       220304 non-null  float64
#  39  sensor_37       220304 non-null  float64
#  40  sensor_38       220293 non-null  float64
#  41  sensor_39       220293 non-null  float64
#  42  sensor_40       220293 non-null  float64
#  43  sensor_41       220293 non-null  float64
#  44  sensor_42       220293 non-null  float64
#  45  sensor_43       220293 non-null  float64
#  46  sensor_44       220293 non-null  float64
#  47  sensor_45       220293 non-null  float64
#  48  sensor_46       220293 non-null  float64
#  49  sensor_47       220293 non-null  float64
#  50  sensor_48       220293 non-null  float64
#  51  sensor_49       220293 non-null  float64
#  52  sensor_50       143303 non-null  float64
#  53  sensor_51       204937 non-null  float64
#  54  machine_status  220320 non-null  object
# dtypes: float64(52), int64(1), object(2)
# memory usage: 92.5+ MB

# %% [markdown]
# <font color='teal'>**Initial Exploratory Data Analysis**</font>
#
# - Count of unique values
# - Numeric columns
# - Missing values
# - Summary stats
# - Outliers
#     - Considerably higher or lower
#     - Require further investigation

# %%
df.nunique()
# Out:
# Unnamed: 0        220320
# timestamp         220320
# sensor_00           1253
# sensor_01            831
# sensor_02            831
# sensor_03            588
# sensor_04           7844
# sensor_05         190751
# sensor_06            812
# sensor_07            531
# sensor_08            626
# sensor_09            565
# sensor_10         198804
# sensor_11         196368
# sensor_12         187145
# sensor_13         191983
# sensor_14          94564
# sensor_15              0
# sensor_16         110522
# sensor_17         148000
# sensor_18         152603
# sensor_19         100422
# sensor_20          92129
# sensor_21         131083
# sensor_22         126401
# sensor_23         119286
# sensor_24         133778
# sensor_25         165999
# sensor_26         179718
# sensor_27         203198
# sensor_28         189278
# sensor_29         201908
# sensor_30           2070
# sensor_31           2685
# sensor_32         205414
# sensor_33         200855
# sensor_34         203895
# sensor_35         201781
# sensor_36         201437
# sensor_37         188898
# sensor_38            602
# sensor_39            909
# sensor_40            878
# sensor_41            594
# sensor_42            699
# sensor_43            713
# sensor_44            628
# sensor_45            675
# sensor_46            845
# sensor_47            621
# sensor_48           1440
# sensor_49            827
# sensor_50           1135
# sensor_51           1108
# machine_status         3
# dtype: int64

# %% [markdown]
# There are two variables, "sensor_15" and "machine_status", I am interested in looking at closely

# %%
# Let's count the unique values of one of the columns
df['machine_status'].value_counts(dropna=False).head()
# Out:
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: machine_status, dtype: int64

# %%
# Let's count the unique values of one of the columns
df['sensor_15'].value_counts(dropna=False).head()
# Out:
# NaN    220320
# Name: sensor_15, dtype: int64

# %% [markdown]
# <font color='teal'>**Let's look at the summary statistics on the remaining columns**</font>

# %%
df.describe().T
# Out:
#                count           mean           std        min           25%  \
# Unnamed: 0  220320.0  110159.500000  63601.049991   0.000000  55079.750000
# sensor_00   210112.0       2.372221      0.412227   0.000000      2.438831
# sensor_01   219951.0      47.591611      3.296666   0.000000     46.310760
# sensor_02   220301.0      50.867392      3.666820  33.159720     50.390620
# sensor_03   220301.0      43.752481      2.418887  31.640620     42.838539
# sensor_04   220301.0     590.673936    144.023912   2.798032    626.620400
# sensor_05   220301.0      73.396414     17.298247   0.000000     69.976260
# sensor_06   215522.0      13.501537      2.163736   0.014468     13.346350
# sensor_07   214869.0      15.843152      2.201155   0.000000     15.907120
# sensor_08   215213.0      15.200721      2.037390   0.028935     15.183740
# sensor_09   215725.0      14.799210      2.091963   0.000000     15.053530
# sensor_10   220301.0      41.470339     12.093519   0.000000     40.705260
# sensor_11   220301.0      41.918319     13.056425   0.000000     38.856420
# sensor_12   220301.0      29.136975     10.113935   0.000000     28.686810
# sensor_13   220301.0       7.078858      6.901755   0.000000      1.538516
# sensor_14   220299.0     376.860041    113.206382  32.409550    418.103250
# sensor_15        0.0            NaN           NaN        NaN           NaN
# sensor_16   220289.0     416.472892    126.072642   0.000000    459.453400
# sensor_17   220274.0     421.127517    129.156175   0.000000    454.138825
# sensor_18   220274.0       2.303785      0.765883   0.000000      2.447542
# sensor_19   220304.0     590.829775    199.345820   0.000000    662.768975
# sensor_20   220304.0     360.805165    101.974118   0.000000    398.021500
# sensor_21   220304.0     796.225942    226.679317  95.527660    875.464400
# sensor_22   220279.0     459.792815    154.528337   0.000000    478.962600
# sensor_23   220304.0     922.609264    291.835280   0.000000    950.922400
# sensor_24   220304.0     556.235397    182.297979   0.000000    601.151050
# sensor_25   220284.0     649.144799    220.865166   0.000000    693.957800
# sensor_26   220300.0     786.411781    246.663608  43.154790    790.489575
# sensor_27   220304.0     501.506589    169.823173   0.000000    448.297950
# sensor_28   220304.0     851.690339    313.074032   4.319347    782.682625
# sensor_29   220248.0     576.195305    225.764091   0.636574    518.947225
# sensor_30   220059.0     614.596442    195.726872   0.000000    627.777800
# sensor_31   220304.0     863.323100    283.544760  23.958330    839.062400
# sensor_32   220252.0     804.283915    260.602361   0.240716    760.607475
# sensor_33   220304.0     486.405980    150.751836   6.460602    489.761075
# sensor_34   220304.0     234.971776     88.376065  54.882370    172.486300
# sensor_35   220304.0     427.129817    141.772519   0.000000    353.176625
# sensor_36   220304.0     593.033876    289.385511   2.260970    288.547575
# sensor_37   220304.0      60.787360     37.604883   0.000000     28.799220
# sensor_38   220293.0      49.655946     10.540397  24.479166     45.572910
# sensor_39   220293.0      36.610444     15.613723  19.270830     32.552080
# sensor_40   220293.0      68.844530     21.371139  23.437500     57.812500
# sensor_41   220293.0      35.365126      7.898665  20.833330     32.552080
# sensor_42   220293.0      35.453455     10.259521  22.135416     32.812500
# sensor_43   220293.0      43.879591     11.044404  24.479166     39.583330
# sensor_44   220293.0      42.656877     11.576355  25.752316     36.747684
# sensor_45   220293.0      43.094984     12.837520  26.331018     36.747684
# sensor_46   220293.0      48.018585     15.641284  26.331018     40.509258
# sensor_47   220293.0      44.340903     10.442437  27.199070     39.062500
# sensor_48   220293.0     150.889044     82.244957  26.331018     83.912030
# sensor_49   220293.0      57.119968     19.143598  26.620370     47.743060
# sensor_50   143303.0     183.049260     65.258650  27.488426    167.534700
# sensor_51   204937.0     202.699667    109.588607  27.777779    179.108800
#
#                       50%            75%            max
# Unnamed: 0  110159.500000  165239.250000  220319.000000
# sensor_00        2.456539       2.499826       2.549016
# sensor_01       48.133678      49.479160      56.727430
# sensor_02       51.649300      52.777770      56.032990
# sensor_03       44.227428      45.312500      48.220490
# sensor_04      632.638916     637.615723     800.000000
# sensor_05       75.576790      80.912150      99.999880
# sensor_06       13.642940      14.539930      22.251160
# sensor_07       16.167530      16.427950      23.596640
# sensor_08       15.494790      15.697340      24.348960
# sensor_09       15.082470      15.118630      25.000000
# sensor_10       44.291340      47.463760      76.106860
# sensor_11       45.363140      49.656540      60.000000
# sensor_12       32.515830      34.939730      45.000000
# sensor_13        2.929809      12.859520      31.187550
# sensor_14      420.106200     420.997100     500.000000
# sensor_15             NaN            NaN            NaN
# sensor_16      462.856100     464.302700     739.741500
# sensor_17      462.020250     466.857075     599.999939
# sensor_18        2.533704       2.587682       4.873250
# sensor_19      665.672400     667.146700     878.917900
# sensor_20      399.367000     400.088400     448.907900
# sensor_21      879.697600     882.129900    1107.526000
# sensor_22      531.855900     534.254850     594.061100
# sensor_23      981.925000    1090.808000    1227.564000
# sensor_24      625.873500     628.607725    1000.000000
# sensor_25      740.203500     750.357125     839.575000
# sensor_26      861.869600     919.104775    1214.420000
# sensor_27      494.468450     536.274550    2000.000000
# sensor_28      967.279850    1043.976500    1841.146000
# sensor_29      564.872500     744.021475    1466.281000
# sensor_30      668.981400     697.222200    1600.000000
# sensor_31      917.708300     981.249900    1800.000000
# sensor_32      878.850750     943.877625    1839.211000
# sensor_33      512.271750     555.163225    1578.600000
# sensor_34      226.356050     316.844950     425.549800
# sensor_35      473.349350     528.891025     694.479126
# sensor_36      709.668050     837.333025     984.060700
# sensor_37       64.295485      90.821928     174.901200
# sensor_38       49.479160      53.645830     417.708300
# sensor_39       35.416660      39.062500     547.916600
# sensor_40       66.406250      77.864580     512.760400
# sensor_41       34.895832      37.760410     420.312500
# sensor_42       35.156250      36.979164     374.218800
# sensor_43       42.968750      46.614580     408.593700
# sensor_44       40.509260      45.138890    1000.000000
# sensor_45       40.219910      44.849540     320.312500
# sensor_46       44.849540      51.215280     370.370400
# sensor_47       42.534720      46.585650     303.530100
# sensor_48      138.020800     208.333300     561.632000
# sensor_49       52.662040      60.763890     464.409700
# sensor_50      193.865700     219.907400    1000.000000
# sensor_51      197.338000     216.724500    1000.000000

# %%
# Histogram
df.hist(df.columns, bins=25, layout=(8,7), figsize=(20, 18))
plt.show()

# %% [markdown]
# ## Data Cleaning
# - Remove redundant columns
# - Remove duplicates
# - Handle missing values
# - Convert data types to the correct data type
#
# Keep in mind: there are data formats that are better for reporting vs. better for analysis; tidy data makes it easier to fix common data problems

# %% [markdown]
# <font color='teal'>**Remove redundant columns**</font>

# %%
# Let's remove the column "Unnamed" as it appears to be a repeated index column
del df['Unnamed: 0']

# %% [markdown]
# <font color='teal'>**Remove duplicates from the dataframe**</font>

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (220320, 54)

# %% [markdown]
# <font color='teal'>**Handle Missing Values**</font>

# %%
# Entire "sensor_15" column is NaN therefore removing the entire column from the data set
del df['sensor_15']

# %%
df.shape
# Out:
# (220320, 53)

# %%
# Function that calculates the percentage of missing values
def calc_percent_NAs(df):
    nans = pd.DataFrame(df.isnull().sum().sort_values(ascending=False)/len(df), columns=['percent']) 
    idx = nans['percent'] > 0
    return nans[idx]

# %%
# Let's take a look at top ten columns with missing values
calc_percent_NAs(df).head(10)
# Out:
#             percent
# sensor_50  0.349569
# sensor_51  0.069821
# sensor_00  0.046333
# sensor_07  0.024741
# sensor_08  0.023180
# sensor_06  0.021777
# sensor_09  0.020856
# sensor_01  0.001675
# sensor_30  0.001185
# sensor_29  0.000327

# %%
df[['sensor_50', 'sensor_51', 'sensor_00', 'sensor_07', 'sensor_08', 'sensor_06', 'sensor_09']].describe().T
# Out:
#               count        mean         std        min         25%  \
# sensor_50  143303.0  183.049260   65.258650  27.488426  167.534700
# sensor_51  204937.0  202.699667  109.588607  27.777779  179.108800
# sensor_00  210112.0    2.372221    0.412227   0.000000    2.438831
# sensor_07  214869.0   15.843152    2.201155   0.000000   15.907120
# sensor_08  215213.0   15.200721    2.037390   0.028935   15.183740
# sensor_06  215522.0   13.501537    2.163736   0.014468   13.346350
# sensor_09  215725.0   14.799210    2.091963   0.000000   15.053530
#
#                   50%         75%          max
# sensor_50  193.865700  219.907400  1000.000000
# sensor_51  197.338000  216.724500  1000.000000
# sensor_00    2.456539    2.499826     2.549016
# sensor_07   16.167530   16.427950    23.596640
# sensor_08   15.494790   15.697340    24.348960
# sensor_06   13.642940   14.539930    22.251160
# sensor_09   15.082470   15.118630    25.000000

# %% [markdown]
# Let's fill NAs in columns sensor_50, sensor_51, sensor_00, sensor_07, sensor_08, sensor_06 and sensor_09 with their mean values as they are 1% of the entire data set. The rest of the columns with NaNs will be removed from the data set.

# %%
df['sensor_50'].fillna((df['sensor_50'].mean()), inplace=True)
df['sensor_51'].fillna((df['sensor_51'].mean()), inplace=True)
df['sensor_00'].fillna((df['sensor_00'].mean()), inplace=True)
df['sensor_08'].fillna((df['sensor_08'].mean()), inplace=True)
df['sensor_07'].fillna((df['sensor_07'].mean()), inplace=True)
df['sensor_06'].fillna((df['sensor_06'].mean()), inplace=True)
df['sensor_09'].fillna((df['sensor_09'].mean()), inplace=True)

# %%
# Let's take a look at top ten columns with missing values
calc_percent_NAs(df).head(10)
# Out:
#             percent
# sensor_01  0.001675
# sensor_30  0.001185
# sensor_29  0.000327
# sensor_32  0.000309
# sensor_18  0.000209
# sensor_17  0.000209
# sensor_22  0.000186
# sensor_25  0.000163
# sensor_16  0.000141
# sensor_40  0.000123

# %%
df_tidy = df.dropna()

# %%
df_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219521 entries, 0 to 220319
# Data columns (total 53 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   timestamp       219521 non-null  object
#  1   sensor_00       219521 non-null  float64
#  2   sensor_01       219521 non-null  float64
#  3   sensor_02       219521 non-null  float64
#  4   sensor_03       219521 non-null  float64
#  5   sensor_04       219521 non-null  float64
#  6   sensor_05       219521 non-null  float64
#  7   sensor_06       219521 non-null  float64
#  8   sensor_07       219521 non-null  float64
#  9   sensor_08       219521 non-null  float64
#  10  sensor_09       219521 non-null  float64
#  11  sensor_10       219521 non-null  float64
#  12  sensor_11       219521 non-null  float64
#  13  sensor_12       219521 non-null  float64
#  14  sensor_13       219521 non-null  float64
#  15  sensor_14       219521 non-null  float64
#  16  sensor_16       219521 non-null  float64
#  17  sensor_17       219521 non-null  float64
#  18  sensor_18       219521 non-null  float64
#  19  sensor_19       219521 non-null  float64
#  20  sensor_20       219521 non-null  float64
#  21  sensor_21       219521 non-null  float64
#  22  sensor_22       219521 non-null  float64
#  23  sensor_23       219521 non-null  float64
#  24  sensor_24       219521 non-null  float64
#  25  sensor_25       219521 non-null  float64
#  26  sensor_26       219521 non-null  float64
#  27  sensor_27       219521 non-null  float64
#  28  sensor_28       219521 non-null  float64
#  29  sensor_29       219521 non-null  float64
#  30  sensor_30       219521 non-null  float64
#  31  sensor_31       219521 non-null  float64
#  32  sensor_32       219521 non-null  float64
#  33  sensor_33       219521 non-null  float64
#  34  sensor_34       219521 non-null  float64
#  35  sensor_35       219521 non-null  float64
#  36  sensor_36       219521 non-null  float64
#  37  sensor_37       219521 non-null  float64
#  38  sensor_38       219521 non-null  float64
#  39  sensor_39       219521 non-null  float64
#  40  sensor_40       219521 non-null  float64
#  41  sensor_41       219521 non-null  float64
#  42  sensor_42       219521 non-null  float64
#  43  sensor_43       219521 non-null  float64
#  44  sensor_44       219521 non-null  float64
#  45  sensor_45       219521 non-null  float64
#  46  sensor_46       219521 non-null  float64
#  47  sensor_47       219521 non-null  float64
#  48  sensor_48       219521 non-null  float64
#  49  sensor_49       219521 non-null  float64
#  50  sensor_50       219521 non-null  float64
#  51  sensor_51       219521 non-null  float64
#  52  machine_status  219521 non-null  object
# dtypes: float64(51), object(2)
# memory usage: 90.4+ MB

# %% [markdown]
# <font color='teal'>**Convert data types to the correct data type**</font>

# %%
# Let's convert the data type of timestamp column to datatime format
df_tidy['Date'] = pd.to_datetime(df_tidy['timestamp'])
df_tidy = df_tidy.drop(['timestamp'], axis=1)
# Out:
# C:\Users\Bauyrjan.Jyenis\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_tidy.head()
# Out:
#    sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  sensor_05  \
# 0   2.465394   47.09201    53.2118  46.310760   634.3750   76.45975
# 1   2.465394   47.09201    53.2118  46.310760   634.3750   76.45975
# 2   2.444734   47.35243    53.2118  46.397570   638.8889   73.54598
# 3   2.460474   47.09201    53.1684  46.397568   628.1250   76.98898
# 4   2.445718   47.13541    53.2118  46.397568   636.4583   76.58897
#
#    sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_44  sensor_45  \
# 0   13.41146   16.13136   15.56713   15.05353  ...  39.641200   65.68287
# 1   13.41146   16.13136   15.56713   15.05353  ...  39.641200   65.68287
# 2   13.32465   16.03733   15.61777   15.01013  ...  39.351852   65.39352
# 3   13.31742   16.24711   15.69734   15.08247  ...  39.062500   64.81481
# 4   13.35359   16.21094   15.69734   15.08247  ...  38.773150   65.10416
#
#    sensor_46  sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  \
# 0   50.92593  38.194440   157.9861   67.70834   243.0556   201.3889
# 1   50.92593  38.194440   157.9861   67.70834   243.0556   201.3889
# 2   51.21528  38.194443   155.9606   67.12963   241.3194   203.7037
# 3   51.21528  38.194440   155.9606   66.84028   240.4514   203.1250
# 4   51.79398  38.773150   158.2755   66.55093   242.1875   201.3889
#
#    machine_status                Date
# 0          NORMAL 2018-04-01 00:00:00
# 1          NORMAL 2018-04-01 00:01:00
# 2          NORMAL 2018-04-01 00:02:00
# 3          NORMAL 2018-04-01 00:03:00
# 4          NORMAL 2018-04-01 00:04:00
#
# [5 rows x 53 columns]

# %% [markdown]
# <font color='teal'>**Let's take a look at the boxplot of the data to see if there are any outliers**</font>

# %%
# Boxplots
bplot = df_tidy.drop(['Date'], axis=1)
boxplots = bplot.boxplot(grid=False, vert=False,fontsize=25, figsize=(12,15))

# %% [markdown]
# As seen in above boxplots, there are outliers in the dataframe.

# %% [markdown]
# <font color='teal'>**Handling outliers**</font>

# %% [markdown]
# The proper action towards handling outliers depends on what causes the outliers. In broad strokes, there are three causes for outliers—data entry or measurement errors, sampling problems and unusual conditions, and natural variation. Since the purpose of this study is focused on anomaly detection, we need to be really careful about how to handle outliers as opposed to just removing them from the dataset. The outliers may represent unusual conditions which may represent the anomalies we are looking for. With that, let's keep the outliers for now and look at them more closely in the next step.

# %% [markdown]
# <font color='teal'>**Let's export the tidy data into a CSV file to be used for analysis**</font>

# %%
path = 'C:\\Users\\Bauyrjan.Jyenis\\Capstone2_Project\\capstone\\data\\interim'
os.chdir(path)

# %%
# Write the dataframe to csv 
df_tidy.to_csv('step2_output_pump.csv')
